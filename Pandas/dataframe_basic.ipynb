# %%
#pandas io
#pandas series opration
import pandas as pd

# %%
import pandas as pd
#df = pd.read_csv(r"C:\Pandas\weather_data.csv")
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017','1/7/2017','1/8/2017','1/9/2017','1/10/2017','1/11/2017','1/12/2017'],
    'temperature': [32,35,28,24,32,31,32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2,6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny','Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df = pd.DataFrame(weather_data)
df   
#df[:]
# Out:
#           day  temperature  windspeed  event
# 0    1/1/2017           32          6   Rain
# 1    1/2/2017           35          7  Sunny
# 2    1/3/2017           28          2   Snow
# 3    1/4/2017           24          7   Snow
# 4    1/5/2017           32          4   Rain
# 5    1/6/2017           31          2  Sunny
# 6    1/7/2017           32          6   Rain
# 7    1/8/2017           35          7  Sunny
# 8    1/9/2017           28          2   Snow
# 9   1/10/2017           24          7   Snow
# 10  1/11/2017           32          4   Rain
# 11  1/12/2017           31          2  Sunny

# %%
#shape will give the dimention of the data 
df.shape
# Out:
# (12, 4)

# %%
rows, columns = df.shape
rows
# Out:
# 12

# %%
columns
# Out:
# 4

# %%
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
df.head(3)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df.tail()
# Out:
#           day  temperature  windspeed  event
# 7    1/8/2017           35          7  Sunny
# 8    1/9/2017           28          2   Snow
# 9   1/10/2017           24          7   Snow
# 10  1/11/2017           32          4   Rain
# 11  1/12/2017           31          2  Sunny

# %%
df.tail(2)
# Out:
#           day  temperature  windspeed  event
# 10  1/11/2017           32          4   Rain
# 11  1/12/2017           31          2  Sunny

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
#df.day 
df["day"]
# Out:
# 0      1/1/2017
# 1      1/2/2017
# 2      1/3/2017
# 3      1/4/2017
# 4      1/5/2017
# 5      1/6/2017
# 6      1/7/2017
# 7      1/8/2017
# 8      1/9/2017
# 9     1/10/2017
# 10    1/11/2017
# 11    1/12/2017
# Name: day, dtype: object

# %%
type(df["event"])
# Out:
# pandas.core.series.Series

# %%
df[["day","event"]]
# Out:
#           day  event
# 0    1/1/2017   Rain
# 1    1/2/2017  Sunny
# 2    1/3/2017   Snow
# 3    1/4/2017   Snow
# 4    1/5/2017   Rain
# 5    1/6/2017  Sunny
# 6    1/7/2017   Rain
# 7    1/8/2017  Sunny
# 8    1/9/2017   Snow
# 9   1/10/2017   Snow
# 10  1/11/2017   Rain
# 11  1/12/2017  Sunny

# %%
a=df["temperature"].max()
b=df["temperature"].mean()
c=df["temperature"].min()
d=df["temperature"].std()
print("max:",a)
print(b)
print(c)
print(d)
# Out:
# max: 35
# 30.333333333333332
# 24
# 3.651483716701107

# %%
#print statistice on data setdf.describe()
df.describe()
# Out:
#        temperature  windspeed
# count    12.000000  12.000000
# mean     30.333333   4.666667
# std       3.651484   2.229282
# min      24.000000   2.000000
# 25%      28.000000   2.000000
# 50%      31.500000   5.000000
# 75%      32.000000   7.000000
# max      35.000000   7.000000

# %%
#df[df.temperature>32]
#df[df.temperature==df.temperature.max()]
#df[df.temperature==df["temperature"].max()]
df[["day","temperature"]][df.temperature==df["temperature"].max()]
# Out:
#         day  temperature
# 1  1/2/2017           35
# 7  1/8/2017           35

# %%
#SET INDEX

# %%
df
# Out:
#           day  temperature  windspeed  event
# 0    1/1/2017           32          6   Rain
# 1    1/2/2017           35          7  Sunny
# 2    1/3/2017           28          2   Snow
# 3    1/4/2017           24          7   Snow
# 4    1/5/2017           32          4   Rain
# 5    1/6/2017           31          2  Sunny
# 6    1/7/2017           32          6   Rain
# 7    1/8/2017           35          7  Sunny
# 8    1/9/2017           28          2   Snow
# 9   1/10/2017           24          7   Snow
# 10  1/11/2017           32          4   Rain
# 11  1/12/2017           31          2  Sunny

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df.set_index("day")
# Out:
#            temperature  windspeed  event
# day
# 1/1/2017            32          6   Rain
# 1/2/2017            35          7  Sunny
# 1/3/2017            28          2   Snow
# 1/4/2017            24          7   Snow
# 1/5/2017            32          4   Rain
# 1/6/2017            31          2  Sunny
# 1/7/2017            32          6   Rain
# 1/8/2017            35          7  Sunny
# 1/9/2017            28          2   Snow
# 1/10/2017           24          7   Snow
# 1/11/2017           32          4   Rain
# 1/12/2017           31          2  Sunny

# %%
df
# Out:
#           day  temperature  windspeed  event
# 0    1/1/2017           32          6   Rain
# 1    1/2/2017           35          7  Sunny
# 2    1/3/2017           28          2   Snow
# 3    1/4/2017           24          7   Snow
# 4    1/5/2017           32          4   Rain
# 5    1/6/2017           31          2  Sunny
# 6    1/7/2017           32          6   Rain
# 7    1/8/2017           35          7  Sunny
# 8    1/9/2017           28          2   Snow
# 9   1/10/2017           24          7   Snow
# 10  1/11/2017           32          4   Rain
# 11  1/12/2017           31          2  Sunny

# %%
df.set_index("day",inplace=True)

# %%
df
# Out:
#            temperature  windspeed  event
# day
# 1/1/2017            32          6   Rain
# 1/2/2017            35          7  Sunny
# 1/3/2017            28          2   Snow
# 1/4/2017            24          7   Snow
# 1/5/2017            32          4   Rain
# 1/6/2017            31          2  Sunny
# 1/7/2017            32          6   Rain
# 1/8/2017            35          7  Sunny
# 1/9/2017            28          2   Snow
# 1/10/2017           24          7   Snow
# 1/11/2017           32          4   Rain
# 1/12/2017           31          2  Sunny

# %%
df.loc["1/1/2017"]
# Out:
# temperature      32
# windspeed         6
# event          Rain
# Name: 1/1/2017, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#           day  temperature  windspeed  event
# 0    1/1/2017           32          6   Rain
# 1    1/2/2017           35          7  Sunny
# 2    1/3/2017           28          2   Snow
# 3    1/4/2017           24          7   Snow
# 4    1/5/2017           32          4   Rain
# 5    1/6/2017           31          2  Sunny
# 6    1/7/2017           32          6   Rain
# 7    1/8/2017           35          7  Sunny
# 8    1/9/2017           28          2   Snow
# 9   1/10/2017           24          7   Snow
# 10  1/11/2017           32          4   Rain
# 11  1/12/2017           31          2  Sunny
